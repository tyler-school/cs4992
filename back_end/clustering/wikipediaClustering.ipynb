# %%
from time import time
import json
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
import matplotlib.pyplot as plt

evaluations = []
evaluations_std = []
contentList = []
matchList = []
true_k = 4

"""
This program is meant to perform clustering on a list of articles, currently called contentList.
Given this list of text, it will cluster them. This creates three sets of important data (might be more to be retrived if wanted)
 - Number of articles in each cluster 
 - Words that are associated with a specific cluster
 - Articles that are in a cluster (This can be replaced with an ID to potentially make processing easier)

For the time being, this information is just printed out to the terminal. 
It could instead easily be packaged into a JSON to send to front-end. 

Issues:
The clustering program was tested with a a significant portion of wikipedia. 

The words which are associated with a cluster may not be the best topic names. 
For example, genus, family, species may show up for science/biology themed articles.
Could pre-identify these names to prettier topics, as these are very common and predictable. 

Clustering requires that a number of clusters is provided, prior to calculating them.
The number of clusters is important in regards to the accuracy of clustering, so the correct number must be chosen.

Traditionally, this is done by performing clustering with a range of cluster sizes, 
and performing an analysis to determine a knee/bend in the data slope-wise. 
This can be quite slow for larger data sets, and for some data sets no distinguishable knee exists. 

Putting an arbitrary cluster size can result in too little or too few clusters. 
Probably want to take a look at this during implementation, shouldn't be too hard to fix using sampling.
"""

#Fetches data that may be useful for testing the model
def getData():
    for x in range(1, 10):
        opener = open('./wikipediaFolder/' + str(x) + '.ext', 'r')
        fcc_data = json.load(opener)
        for i in fcc_data:
            contentList.append(i["text"])

    for x in range(0, len(contentList)):
        matchList.append(x)

getData()

#performs the fit a few times, using random seeds
def fit_and_evaluate(km, X, name=None, n_runs=1):
    name = km.__class__.__name__ if name is None else name
    for seed in range(n_runs):
        km.set_params(random_state=seed)
        km.fit(X)


#Creates a vectorizer, setting guidelines as to how text should be processed/reduced
vectorizer = TfidfVectorizer(
    max_df=0.5,
    min_df=5,
    stop_words="english",
)

#Performs the actual vectorization on the list of articles, using lsa for speed improvements
t0 = time()
X_tfidf = vectorizer.fit_transform(contentList)
lsa = make_pipeline(TruncatedSVD(n_components=100), Normalizer(copy=False))
t0 = time()
X_lsa = lsa.fit_transform(X_tfidf)
explained_variance = lsa[0].explained_variance_ratio_.sum()
print(f"LSA done in {time() - t0:.3f} s")
print(f"Explained variance of the SVD step: {explained_variance * 100:.1f}%")



#Given the vectorized content, we can go about running the model
kmeans = KMeans(
    n_clusters=true_k,
    max_iter=100,
    n_init=1,
)
fit_and_evaluate(kmeans, X_lsa, name="KMeans\nwith LSA on tf-idf vectors")

#Fetch the terms associated with a cluster. This can become a cluster name.
original_space_centroids = lsa[0].inverse_transform(kmeans.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()

for i in range(true_k):
    print(f"Cluster {i}: ", end="")
    for ind in order_centroids[i, :20]:
        print(f"{terms[ind]} ", end="")
    print()


#Get what cluster a specific article is in, and print it out. 
labels=kmeans.labels_
clusters=pd.DataFrame(list(zip(contentList,labels)),columns=['title','cluster'])
print(clusters.sort_values(by=['cluster']))

for i in range(true_k):
    print(clusters[clusters['cluster'] == i])
# Out:
# LSA done in 239.221 s
# Explained variance of the SVD step: 12.3%
# Cluster 0: species genus family described genera fish tachinidae endemic marine flora monotypic plant plants taxa sea gastropod australia south description fungi
# Cluster 1: university american century new art people published book school music college books writers work women york english award born science
# Cluster 2: films film series television company used based american time new research companies data episode use game group aircraft software language
# Cluster 3: born olympics people summer surname refer american olympic championships games living player births medalists male italian competed world team footballer
# Cluster 4: district village population county province municipality villages populated census places rural voivodeship poland gmina administrative north lies east south located
# Cluster 5: align album style center albums left width background band song text released songs music scope rowspan chart vocals bgcolor track
# Cluster 6: county station river railway south park historic school north church located area city west building road state town new national
# Cluster 7: described species family moths articles qbugbot created beetles beetle moth america endemic reading north polbot insects taxonomy amphibians habitat tropical
# Cluster 8: party war people election united general army members served member state states law house court british new government military politicians
# Cluster 9: players football league footballers team season club played cup fc colspan expatriate association career goals division people basketball footballer coach
#                                                     title  cluster
# 429004  Microsveltia patricia is a species of sea snai...        0
# 594393  Pardosa kratochvili is a wolf spider species i...        0
# 921700  Saitis chaperi is a species of spider of the g...        0
# 921701  Saitis kandyensis is a species of spider of th...        0
# 979307  Carychiinae is a taxonomic subfamily of minute...        0
# ...                                                   ...      ...
# 174141  Andrew McCarthy (born 20 October 1998) is a Sc...        9
# 174142  Gustavo Martin Emilio Hamer (born 24 June 1997...        9
# 174153  The 1967 Sacramento State Hornets football tea...        9
# 173875  Arnold Abelinti (born 9 September 1991) is a F...        9
# 939756  Alexander Mathias "Babe" Weyand (January 10, 1...        9
#
# [1253636 rows x 2 columns]
#                                                      title  cluster
# 5        Sabellida is an order of annelid worms in the ...        0
# 291      Rhododendron spinuliferum is a species of Rhod...        0
# 437      Carnidae, also known as Bird flies or Filth fl...        0
# 455      Trichomycterus guaraquessaba is a species of p...        0
# 466      Eurostopodus is a genus of eared nightjar in t...        0
# ...                                                    ...      ...
# 1253615  Trimeresurus purpureomaculatus is a venomous p...        0
# 1253616  Trimeresurus septentrionalis, commonly known a...        0
# 1253620  Trimeresurus stejnegeri is a species of venomo...        0
# 1253621  Armina sp. from East Timor. A. gilchristi from...        0
# 1253633  Ahaetulla prasina is a species of snake in the...        0
#
# [54073 rows x 2 columns]
#                                                      title  cluster
# 21       Gary Conklin is an independent American filmma...        1
# 33       A heraldic alphyn An Alphyn (from the Germanic...        1
# 36       Lawrence Edmund Spivak (June 11, 1900 – March ...        1
# 38       Robert Joseph is a British wine expert, consul...        1
# 41       Tserents (, born Hovsep Shishmanyan, (): Septe...        1
# ...                                                    ...      ...
# 1253578  Dragonstorm is a fantasy novel written by Grah...        1
# 1253579  A broader list of English Bible translations i...        1
# 1253585  Alfred Yi Cho (; born July 10, 1937UC Santa Cr...        1
# 1253593  K. N. Sitaram (1889-1940) was the first Indian...        1
# 1253628  Barry Mitchell (born March 6, 1952) is a Brook...        1
#
# [166410 rows x 2 columns]
#                                                      title  cluster
# 1        In sociology, dynamic density refers to the co...        2
# 15       mSv or MSV may refer to: * Maize streak virus,...        2
# 29       The Wealthy Barber, full title (The Wealthy Ba...        2
# 42       Chlormint is a product line of chewing gum and...        2
# 43       thumb|150px|right|Equatorial Inertial wave pul...        2
# ...                                                    ...      ...
# 1253574  Manual for v3.2 of Spitfire BBS SPITFIRE (BBS)...        2
# 1253576  Phreaking boxes are devices used by phone phre...        2
# 1253587  Cyclic stress is the distribution of forces (a...        2
# 1253590  Dynamic Multipoint Virtual Private Network (DM...        2
# 1253614  NSB El 9 is a retired class of three electric ...        2
#
# [174115 rows x 2 columns]
#                                                      title  cluster
# 20       The 2005 New England Grand Prix was the fourth...        3
# 23       Timea Majorova (born October 2, 1974 in Bratis...        3
# 27       Stockwell is a district in inner South London,...        3
# 39       Michael or Mike Genovese may refer to: * Micha...        3
# 47       Derek Almstead (born August 23, 1974) is an Am...        3
# ...                                                    ...      ...
# 1253570  Francis Anthony Ward (23 February 1906, Sydney...        3
# 1253575  Benjamin Arthur Barnett (23 March 1908 – 29 Ju...        3
# 1253618  Vlah is a surname, a reference to Vlachs. Nota...        3
# 1253630  Ernest Raymond Herbert Toshack (8 December 191...        3
# 1253632  Azam Khan (Pashto: اعظم خان; 20 April 1926Azam...        3
#
# [125592 rows x 2 columns]
#                                                      title  cluster
# 125      Amli is a census town in the Union Territory o...        4
# 236      Londiani is a Kenyan town in the Kericho Count...        4
# 246      The Shire of Broome is one of the four local g...        4
# 326      Mueang Narathiwat (, ) is the capital district...        4
# 395      Phanom Sarakham District (, ) is a district (a...        4
# ...                                                    ...      ...
# 1253623  Erimayur is a gram panchayat in the Palakkad d...        4
# 1253624  Kannambra is a gram panchayat in the Palakkad ...        4
# 1253626  Kavassery is a gram panchayat in the Palakkad ...        4
# 1253627  Kizhakkancherry is a gram panchayat in the Pal...        4
# 1253629  Kottayi may refer to *Kottayi-I, a village in ...        4
#
# [85058 rows x 2 columns]
#                                                      title  cluster
# 6        Cedar! is the debut album by pianist Cedar Wal...        5
# 8        Conforming to Abnormality is Cephalic Carnage'...        5
# 13       Exploiting Dysfunction is Cephalic Carnage's s...        5
# 17       Halls of Amenti is a one-song EP by Cephalic C...        5
# 25       Lucid Interval is the third full-length album ...        5
# ...                                                    ...      ...
# 1253617  Seven Year Ache is the third studio album by A...        5
# 1253622  Somewhere in the Stars is the fourth studio al...        5
# 1253625  Rhythm & Romance was the fifth studio album by...        5
# 1253631  King's Record Shop is the sixth studio album b...        5
# 1253635  Hungary competed at the 1900 Summer Olympics i...        5
#
# [137779 rows x 2 columns]
#                                                      title  cluster
# 0        M-137 was a state trunkline highway in the US ...        6
# 4        Ghelamco Arena panorama indoor. The Ghelamco A...        6
# 9        Somersville Towne Center is a regional shoppin...        6
# 10       Racine Lutheran High School is a private relig...        6
# 12       Union College is a heritage-listed residential...        6
# ...                                                    ...      ...
# 1253591  Protobothrops jerdonii (Jerdon's pitviper,Brow...        6
# 1253599  U.S. Route 180 Location of the Mogollon Mounta...        6
# 1253607  Bison herd grazing at the National Bison Range...        6
# 1253611  Westfield Doncaster (formerly Doncaster Shoppi...        6
# 1253634  The Serchio (; ) is the third longest river in...        6
#
# [194168 rows x 2 columns]
#                                                      title  cluster
# 1767     Duttaphrynus silentvalleyensis, also known as ...        7
# 1771     Duttaphrynus stomaticus, also known as the Ind...        7
# 1772     Bufo stuarti is a species of toad found in Sou...        7
# 1781     Leptobrachium smithi (common name Smith's litt...        7
# 1783     Scutiger boulengeri (common names: Boulenger's...        7
# ...                                                    ...      ...
# 1245386  This is a family tree of the Habsburg family. ...        7
# 1247920  Oedipina complex, commonly known as the Gamboa...        7
# 1250055  The Lithuanian Wikipedia () is the Lithuanian ...        7
# 1251372  The Andic languages are a branch of the Northe...        7
# 1253178  Industrial melanism is an evolutionary effect ...        7
#
# [48257 rows x 2 columns]
#                                                      title  cluster
# 7        Prince Fereydoun Mirza (born between 1810 and ...        8
# 11       Diego Félix of Austria, Prince of Asturias and...        8
# 28       Jail Killing Day () is observed by the Awami L...        8
# 32       Empress Wang (王皇后, personal name unknown) (die...        8
# 65       {| |} USCGC Valiant (WMEC-621) is a United Sta...        8
# ...                                                    ...      ...
# 1253523  Memorial erected in 1885, near Greencastle, Pe...        8
# 1253530  Liu Yuan (劉淵) (died 310), courtesy name Yuanha...        8
# 1253561  The Wootton Report on cannabis (dated 1968 and...        8
# 1253596  Thami El Glaoui (; 1879–23 January 1956), know...        8
# 1253619  Operation Python, a follow-up to Operation Tri...        8
#
# [175668 rows x 2 columns]
#                                                      title  cluster
# 2        Bert Robert Shepard (June 20, 1920 – June 16, ...        9
# 3        Marc Fein (born Marc Alan Fein October 21, 196...        9
# 14       ==Current shows== {| class="wikitable" ! Progr...        9
# 26       The Alabama Crimson Tide football program repr...        9
# 30       Sam William Gagner (born August 10, 1989) is a...        9
# ...                                                    ...      ...
# 1253573  Tony Chursky (born June 13, 1953 in New Westmi...        9
# 1253584  Mervyn George Waite (7 January 1911 – 16 Decem...        9
# 1253595  Robert "Bob" Bolitho (born July 20, 1952 in Vi...        9
# 1253597  Manfred Pohlschmidt (born 27 August 1940) is a...        9
# 1253604  Kenneth Paul Dolan (born April 16, 1966) is a ...        9
#
# [92516 rows x 2 columns]
